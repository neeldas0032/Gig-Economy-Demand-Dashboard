# %%
import pandas as pd

# %%
df = pd.read_csv('../data/plfs_person_2022_23.csv', low_memory=False)

# %%
df.head()
# Out:
#    P3  CFVP3  104  Q7  V1  1  28  03  281  01  ...  0.28  11.7  01.12  611.1  \
# 0  P3  CFVP3  104  Q7  V1  1  28   3  281   1  ...     0    99    NaN    NaN
# 1  P3  CFVP3  104  Q7  V1  1  28   3  281   1  ...     0    99    NaN    NaN
# 2  P3  CFVP3  104  Q7  V1  1  28   3  281   1  ...     0    99    NaN    NaN
# 3  P3  CFVP3  104  Q7  V1  1  28   3  281   1  ...     0    93    NaN    NaN
# 4  P3  CFVP3  104  Q7  V1  1  28   3  281   1  ...     0    21    1.0  611.0
#
#    0.29  15000  1.11  2.2  2659089  2.3
# 0     0      0     1    2  2659089    2
# 1     0      0     1    2  2659089    2
# 2     0      0     1    2  2659089    2
# 3     0      0     1    2  2659089    2
# 4     0      0     1    2  2659089    2
#
# [5 rows x 140 columns]

# %%
df.columns
# Out:
# Index(['P3', 'CFVP3', '104', 'Q7', 'V1', '1', '28', '03', '281', '01',
#        ...
#        '0.28', '11.7', '01.12', '611.1', '0.29', '15000', '1.11', '2.2',
#        '2659089', '2.3'],
#       dtype='object', length=140)

# %%
df.shape
# Out:
# (416331, 140)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 416331 entries, 0 to 416330
# Columns: 140 entries, P3 to 2.3
# dtypes: float64(57), int64(79), object(4)
# memory usage: 444.7+ MB

# %%
df[['104', '611.1', '15000']].head()
# Out:
#    104  611.1  15000
# 0  104    NaN      0
# 1  104    NaN      0
# 2  104    NaN      0
# 3  104    NaN      0
# 4  104  611.0      0

# %%
df['104'].value_counts().head()
# Out:
# 104
# 104    416331
# Name: count, dtype: int64

# %%
df['611.1'].value_counts().head()
# Out:
# 611.1
# 611.0    33385
# 522.0    15678
# 931.0    12526
# 921.0     8834
# 612.0     8450
# Name: count, dtype: int64

# %%
df['15000'].value_counts().head()
# Out:
# 15000
# 0        346903
# 15000      4784
# 12000      3519
# 10000      2897
# 20000      2820
# Name: count, dtype: int64

# %%
df
# Out:
#         P3  CFVP3  104  Q7  V1  1  28  03  281  01  ...  0.28  11.7  01.12  \
# 0       P3  CFVP3  104  Q7  V1  1  28   3  281   1  ...     0    99    NaN
# 1       P3  CFVP3  104  Q7  V1  1  28   3  281   1  ...     0    99    NaN
# 2       P3  CFVP3  104  Q7  V1  1  28   3  281   1  ...     0    99    NaN
# 3       P3  CFVP3  104  Q7  V1  1  28   3  281   1  ...     0    93    NaN
# 4       P3  CFVP3  104  Q7  V1  1  28   3  281   1  ...     0    21    1.0
# ...     ..    ...  ...  ..  .. ..  ..  ..  ...  ..  ...   ...   ...    ...
# 416326  P4  CFVP3  104  Q2  V1  2  34   2  341   3  ...     0    94    NaN
# 416327  P4  CFVP3  104  Q2  V1  2  34   2  341   3  ...     0    92    NaN
# 416328  P4  CFVP3  104  Q2  V1  2  34   2  341   3  ...     0    31   14.0
# 416329  P4  CFVP3  104  Q2  V1  2  34   2  341   3  ...     0    92    NaN
# 416330  P4  CFVP3  104  Q2  V1  2  34   2  341   3  ...     0    31   97.0
#
#         611.1   0.29  15000  1.11  2.2  2659089  2.3
# ...

# %%
df = df.rename(columns={
    '15000': 'earnings',
    '611.1': 'occupation_code'
})

# %%
df[['earnings', 'occupation_code']].head()
# Out:
#    earnings  occupation_code
# 0         0              NaN
# 1         0              NaN
# 2         0              NaN
# 3         0              NaN
# 4         0            611.0

# %%
df = df[df['earnings'] > 0]

# %%
df['earnings'].describe()
# Out:
# count     69395.000000
# mean      13789.139232
# std       13072.948369
# min         250.000000
# 25%        6000.000000
# 50%       12000.000000
# 75%       18000.000000
# max      500000.000000
# Name: earnings, dtype: float64

# %%
df['earnings'].mean()
# Out:
# np.float64(13789.139231933137)

# %%
df['earnings'].median()
# Out:
# np.float64(12000.0)

# %%
df['occupation_code'].value_counts().head(10)
# Out:
# occupation_code
# 611.0    19584
# 522.0     9383
# 612.0     6736
# 832.0     3940
# 112.0     3884
# 753.0     3206
# 613.0     3067
# 631.0     1494
# 521.0     1365
# 731.0     1348
# Name: count, dtype: int64

# %%
df = df.rename(columns={
    '15000': 'earnings',
    '611.1': 'occupation_code'
})

df = df[df['earnings'] > 0]

df['earnings'].describe()
# Out:
# count     69395.000000
# mean      13789.139232
# std       13072.948369
# min         250.000000
# 25%        6000.000000
# 50%       12000.000000
# 75%       18000.000000
# max      500000.000000
# Name: earnings, dtype: float64

# %%
df['occupation_code'].value_counts().head(15)
# Out:
# occupation_code
# 611.0    19584
# 522.0     9383
# 612.0     6736
# 832.0     3940
# 112.0     3884
# 753.0     3206
# 613.0     3067
# 631.0     1494
# 521.0     1365
# 731.0     1348
# 711.0     1289
# 751.0     1200
# 723.0      746
# 514.0      684
# 121.0      595
# Name: count, dtype: int64

# %%
gig_codes = [832.0, 753.0, 522.0]

gig_workers = df[df['occupation_code'].isin(gig_codes)]

# %%
gig_workers.head()
# Out:
#     P3  CFVP3  104  Q7  V1  1  28  03  281  01  ...  0.28  11.7  01.12  \
# 7   P3  CFVP3  104  Q7  V1  1  28   3  281   1  ...     0    11   49.0
# 15  P3  CFVP3  104  Q7  V1  1  28   3  281   1  ...     0    11   49.0
# 22  P3  CFVP3  104  Q7  V1  1  28   3  281   1  ...     0    11   49.0
# 38  P3  CFVP3  104  Q7  V1  1  28   4  281   1  ...     0    11   49.0
# 71  P3  CFVP3  104  Q7  V1  1  28   4  281   1  ...     0    11   47.0
#
#     occupation_code  0.29  earnings  1.11  2.2  2659089  2.3
# 7             832.0     0      8500     1    2  2659089    2
# 15            832.0     0      9000     1    2  2737297    2
# 22            832.0     0     15000     1    2  2737297    2
# 38            832.0     0     20000     1    2  3563286    2
# 71            522.0     0     14000     1    2  1184507    2
#
# [5 rows x 140 columns]

# %%
gig_workers['earnings'].describe()
# Out:
# count     16529.000000
# mean      14728.701797
# std        9517.600898
# min         250.000000
# 25%        8500.000000
# 50%       14000.000000
# 75%       18560.000000
# max      210000.000000
# Name: earnings, dtype: float64

# %%
df['earnings'].mean()
# Out:
# np.float64(13789.139231933137)

# %%
gig_workers['earnings'].mean()
# Out:
# np.float64(14728.701796841915)

# %%
df['occupation_code'].value_counts().head(15)
# Out:
# occupation_code
# 611.0    19584
# 522.0     9383
# 612.0     6736
# 832.0     3940
# 112.0     3884
# 753.0     3206
# 613.0     3067
# 631.0     1494
# 521.0     1365
# 731.0     1348
# 711.0     1289
# 751.0     1200
# 723.0      746
# 514.0      684
# 121.0      595
# Name: count, dtype: int64

# %%
gig_codes = [832.0, 753.0, 522.0]

gig_workers = df[df['occupation_code'].isin(gig_codes)]

gig_workers['earnings'].describe()
# Out:
# count     16529.000000
# mean      14728.701797
# std        9517.600898
# min         250.000000
# 25%        8500.000000
# 50%       14000.000000
# 75%       18560.000000
# max      210000.000000
# Name: earnings, dtype: float64

# %%
df['earnings'].median()
# Out:
# np.float64(12000.0)

# %%
gig_workers['earnings'].median()
# Out:
# np.float64(14000.0)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,5))

plt.hist(df['earnings'], bins=50, alpha=0.5, label='All Workers')
plt.hist(gig_workers['earnings'], bins=50, alpha=0.5, label='Gig Workers')

plt.legend()
plt.title('Earnings Distribution')
plt.xlabel('Earnings')
plt.ylabel('Count')

plt.show()

# %%
df['earnings'].quantile([0.25, 0.5, 0.75])
# Out:
# 0.25     6000.0
# 0.50    12000.0
# 0.75    18000.0
# Name: earnings, dtype: float64

# %%
gig_workers['earnings'].quantile([0.25, 0.5, 0.75])
# Out:
# 0.25     8500.0
# 0.50    14000.0
# 0.75    18560.0
# Name: earnings, dtype: float64

# %%
gig_codes = [832.0, 753.0, 522.0]

# %%
df['earnings'].median()
# Out:
# np.float64(12000.0)

# %%
gig_workers['earnings'].median()
# Out:
# np.float64(14000.0)

# %%
gig_workers['earnings'].quantile([0.25, 0.5, 0.75])
# Out:
# 0.25     8500.0
# 0.50    14000.0
# 0.75    18560.0
# Name: earnings, dtype: float64

# %%
gig_codes = [832.0, 753.0]

# %%
gig_workers = df[df['occupation_code'].isin(gig_codes)]

# %%
gig_workers['earnings'].median()
# Out:
# np.float64(12000.0)

# %%
plt.figure(figsize=(8,5))

plt.boxplot([df['earnings'], gig_workers['earnings']],
            tick_labels=['All Workers', 'Gig Workers'])

plt.title('Earnings Comparison')
plt.ylabel('Monthly Earnings')

plt.show()

# %%
plt.boxplot([df['earnings'], gig_workers['earnings']],
            tick_labels=['All Workers', 'Gig Workers'],
            showfliers=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x19a858dd160>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x19a858ddc40>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x19a858df4a0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x19a85b39010>,
# ...
#  'fliers': [],
#  'means': []}

# %%
import os
os.listdir('../data')
# Out:
# ['cperv1.txt', 'daily-rainfall-at-state-level.csv', 'plfs_person_2022_23.csv']

# %%
weather = pd.read_csv('../data/daily-rainfall-at-state-level.csv')

# %%
weather.head()
# Out:
#    id        date  state_code        state_name  actual       rfs  normal  \
# 0   0  2009-01-01           5       Uttarakhand     0.0  0.003906    2.19
# 1   1  2009-01-01          18             Assam     0.0  0.000000    0.52
# 2   2  2009-01-01          16           Tripura     0.0  0.000000    0.09
# 3   3  2009-01-01          36         Telangana     0.0  0.000000    0.17
# 4   4  2009-01-01           2  Himachal Pradesh     0.0  0.008566    3.31
#
#    deviation
# 0     -100.0
# 1     -100.0
# 2     -100.0
# 3     -100.0
# 4     -100.0

# %%
weather.columns
# Out:
# Index(['id', 'date', 'state_code', 'state_name', 'actual', 'rfs', 'normal',
#        'deviation'],
#       dtype='object')

# %%
weather = weather[['state_name', 'actual']]

# %%
weather = weather.rename(columns={
    'actual': 'rainfall'
})

# %%
weather_state = weather.groupby('state_name')['rainfall'].mean().reset_index()

# %%
weather_state.head()
# Out:
#                     state_name  rainfall
# 0  Andaman And Nicobar Islands       NaN
# 1               Andhra Pradesh  2.567077
# 2            Arunachal Pradesh  6.525427
# 3                        Assam  5.324927
# 4                        Bihar  3.021938

# %%
import numpy as np

states = weather_state['state_name'].unique()

df['state_name'] = np.random.choice(states, size=len(df))

# %%
merged_df = df.merge(weather_state, on='state_name', how='left')

# %%
merged_df.head()
# Out:
#    P3  CFVP3  104  Q7  V1  1  28  03  281  01  ...  01.12  occupation_code  \
# 0  P3  CFVP3  104  Q7  V1  1  28   3  281   1  ...    1.0            611.0
# 1  P3  CFVP3  104  Q7  V1  1  28   3  281   1  ...   49.0            832.0
# 2  P3  CFVP3  104  Q7  V1  1  28   3  281   1  ...    1.0            611.0
# 3  P3  CFVP3  104  Q7  V1  1  28   3  281   1  ...    1.0            611.0
# 4  P3  CFVP3  104  Q7  V1  1  28   3  281   1  ...   49.0            832.0
#
#    0.29  earnings  1.11  2.2  2659089  2.3   state_name  rainfall
# 0     0     15000     1    2  2659089    2      Haryana  1.448982
# 1     0      8500     1    2  2659089    2    Meghalaya  9.686787
# 2     0     12000     1    2  2737297    2    Telangana  2.822724
# 3     0     12500     1    2  2737297    2  Uttarakhand  3.996805
# 4     0      9000     1    2  2737297    2    Jharkhand  3.177312
#
# [5 rows x 142 columns]

# %%
merged_df['rain_flag'] = merged_df['rainfall'].apply(lambda x: 1 if x > 0 else 0)

# %%
merged_df['estimated_orders'] = merged_df['earnings'] / 50

# %%
merged_df[['rainfall', 'estimated_orders']].corr()
# Out:
#                   rainfall  estimated_orders
# rainfall          1.000000         -0.004733
# estimated_orders -0.004733          1.000000

# %%
import matplotlib.pyplot as plt

plt.scatter(merged_df['rainfall'], merged_df['estimated_orders'])
plt.xlabel('Rainfall')
plt.ylabel('Estimated Orders')
plt.title('Rain vs Demand')
plt.show()

# %%
merged_df.head()
# Out:
#    P3  CFVP3  104  Q7  V1  1  28  03  281  01  ...  0.29  earnings  1.11  2.2  \
# 0  P3  CFVP3  104  Q7  V1  1  28   3  281   1  ...     0     15000     1    2
# 1  P3  CFVP3  104  Q7  V1  1  28   3  281   1  ...     0      8500     1    2
# 2  P3  CFVP3  104  Q7  V1  1  28   3  281   1  ...     0     12000     1    2
# 3  P3  CFVP3  104  Q7  V1  1  28   3  281   1  ...     0     12500     1    2
# 4  P3  CFVP3  104  Q7  V1  1  28   3  281   1  ...     0      9000     1    2
#
#    2659089  2.3   state_name  rainfall  rain_flag  estimated_orders
# 0  2659089    2      Haryana  1.448982          1             300.0
# 1  2659089    2    Meghalaya  9.686787          1             170.0
# 2  2737297    2    Telangana  2.822724          1             240.0
# 3  2737297    2  Uttarakhand  3.996805          1             250.0
# 4  2737297    2    Jharkhand  3.177312          1             180.0
#
# [5 rows x 144 columns]

# %%
grouped = merged_df.groupby('state_name')[['rainfall', 'estimated_orders']].mean().reset_index()

# %%
import matplotlib.pyplot as plt

plt.scatter(grouped['rainfall'], grouped['estimated_orders'])

for i in range(len(grouped)):
    plt.text(grouped['rainfall'][i], grouped['estimated_orders'][i], grouped['state_name'][i], fontsize=8)

plt.xlabel('Rainfall')
plt.ylabel('Estimated Orders')
plt.title('Rain vs Demand (State Level)')
plt.show()

# %%
grouped[['rainfall', 'estimated_orders']].corr()
# Out:
#                   rainfall  estimated_orders
# rainfall          1.000000         -0.161238
# estimated_orders -0.161238          1.000000

# %%
merged_df.groupby('rain_flag')['estimated_orders'].mean()
# Out:
# rain_flag
# 0    282.266293
# 1    275.395770
# Name: estimated_orders, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

X = merged_df[['rainfall']]
y = merged_df['estimated_orders']

model = LinearRegression()
model.fit(X, y)

print("Impact of rainfall on demand:", model.coef_[0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[68], line 7
#       4 y = merged_df['estimated_orders']
#       6 model = LinearRegression()
# ----> 7 model.fit(X, y)
#       9 print("Impact of rainfall on demand:", model.coef_[0])
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_base.py:630, in LinearRegression.fit(self, X, y, sample_weight)
#     626 n_jobs_ = self.n_jobs
# ...

# %%
merged_df[['rainfall', 'estimated_orders']].isnull().sum()
# Out:
# rainfall            3909
# estimated_orders       0
# dtype: int64

# %%
clean_df = merged_df[['rainfall', 'estimated_orders']].dropna()

# %%
X = clean_df[['rainfall']]
y = clean_df['estimated_orders']

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X, y)

print("Impact of rainfall on demand:", model.coef_[0])
# Out:
# Impact of rainfall on demand: -0.5656651248004825

# %%
clean_df['rainfall'] = pd.to_numeric(clean_df['rainfall'], errors='coerce')
clean_df['estimated_orders'] = pd.to_numeric(clean_df['estimated_orders'], errors='coerce')

clean_df = clean_df.dropna()

# %%
from sklearn.linear_model import LinearRegression
import pandas as pd

# Clean data
clean_df = merged_df[['rainfall', 'estimated_orders']].copy()

clean_df['rainfall'] = pd.to_numeric(clean_df['rainfall'], errors='coerce')
clean_df['estimated_orders'] = pd.to_numeric(clean_df['estimated_orders'], errors='coerce')

clean_df = clean_df.dropna()

# Train model
X = clean_df[['rainfall']]
y = clean_df['estimated_orders']

model = LinearRegression()
model.fit(X, y)

print("Impact of rainfall on demand:", model.coef_[0])
# Out:
# Impact of rainfall on demand: -0.5656651248004825

# %%
merged_df['rain_intensity'] = merged_df['rainfall'] * 10

# %%
merged_df['rain_flag'] = (merged_df['rainfall'] > 2).astype(int)

# %%
clean_df = merged_df[['rainfall', 'rain_intensity', 'rain_flag', 'estimated_orders']].copy()

clean_df = clean_df.dropna()

# %%
from sklearn.linear_model import LinearRegression

X = clean_df[['rainfall', 'rain_intensity', 'rain_flag']]
y = clean_df['estimated_orders']

model = LinearRegression()
model.fit(X, y)

print("Model Coefficients:", model.coef_)
# Out:
# Model Coefficients: [-2.84315884e-03 -2.84315884e-02 -3.59480984e+00]

# %%
model.coef_
# Out:
# array([-2.84315884e-03, -2.84315884e-02, -3.59480984e+00])

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)

rf_model.fit(X, y)
# Out:
# RandomForestRegressor(random_state=42)

# %%
import pandas as pd

importance = pd.DataFrame({
    'feature': X.columns,
    'importance': rf_model.feature_importances_
}).sort_values(by='importance', ascending=False)

importance
# Out:
#           feature  importance
# 1  rain_intensity    0.515816
# 0        rainfall    0.479493
# 2       rain_flag    0.004691

# %%
import matplotlib.pyplot as plt

plt.bar(importance['feature'], importance['importance'])
plt.title("Feature Importance")
plt.show()

# %%
importance
# Out:
#           feature  importance
# 1  rain_intensity    0.515816
# 0        rainfall    0.479493
# 2       rain_flag    0.004691

# %%
income = merged_df['real_income'].dropna().values
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'real_income'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[85], line 1
# ...

# %%
merged_df.columns
# Out:
# Index(['P3', 'CFVP3', '104', 'Q7', 'V1', '1', '28', '03', '281', '01',
#        ...
#        'earnings', '1.11', '2.2', '2659089', '2.3', 'state_name', 'rainfall',
#        'rain_flag', 'estimated_orders', 'rain_intensity'],
#       dtype='object', length=145)

# %%
merged_df['expenses'] = merged_df['earnings'] * 0.25

# %%
merged_df['real_income'] = merged_df['earnings'] - merged_df['expenses']

# %%
merged_df[['earnings', 'expenses', 'real_income']].head()
# Out:
#    earnings  expenses  real_income
# 0     15000    3750.0      11250.0
# 1      8500    2125.0       6375.0
# 2     12000    3000.0       9000.0
# 3     12500    3125.0       9375.0
# 4      9000    2250.0       6750.0

# %%
income = merged_df['real_income'].dropna().values

# %%
import numpy as np

def gini(array):
    array = np.sort(array)
    n = len(array)
    index = np.arange(1, n + 1)
    return (np.sum((2 * index - n - 1) * array)) / (n * np.sum(array))

# %%
gini_value = gini(income)
print("Gini Index:", gini_value)
# Out:
# Gini Index: 0.4135101422917929

# %%
features = merged_df[['real_income', 'rainfall', 'estimated_orders']].dropna()

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaled_data = scaler.fit_transform(features)

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=3, random_state=42)
features['cluster'] = kmeans.fit_predict(scaled_data)

# %%
features.head()
# Out:
#    real_income  rainfall  estimated_orders  cluster
# 0      11250.0  1.448982             300.0        2
# 1       6375.0  9.686787             170.0        0
# 2       9000.0  2.822724             240.0        2
# 3       9375.0  3.996805             250.0        2
# 4       6750.0  3.177312             180.0        2

# %%
features.groupby('cluster').mean()
# Out:
#           real_income  rainfall  estimated_orders
# cluster
# 0         8538.690820  7.096556        227.698422
# 1        32610.067414  3.719737        869.601798
# 2         8284.880859  2.887089        220.930156

# %%
import matplotlib.pyplot as plt

plt.scatter(features['real_income'], features['estimated_orders'], c=features['cluster'])
plt.xlabel("Real Income")
plt.ylabel("Orders")
plt.title("Worker Segmentation")
plt.show()

# %%
features.groupby('cluster').mean()
# Out:
#           real_income  rainfall  estimated_orders
# cluster
# 0         8538.690820  7.096556        227.698422
# 1        32610.067414  3.719737        869.601798
# 2         8284.880859  2.887089        220.930156

# %%
def predict_orders(rainfall):
    rain_intensity = rainfall * 10
    rain_flag = 1 if rainfall > 2 else 0
    
    input_data = [[rainfall, rain_intensity, rain_flag]]
    
    prediction = rf_model.predict(input_data)
    
    return prediction[0]

# %%
print("Predicted Orders (Rainfall=1):", predict_orders(1))
print("Predicted Orders (Rainfall=5):", predict_orders(5))
print("Predicted Orders (Rainfall=10):", predict_orders(10))
# Out:
# Predicted Orders (Rainfall=1): 274.9020037370117
# Predicted Orders (Rainfall=5): 284.7217493809072
# Predicted Orders (Rainfall=10): 270.92554267228786
# C:\Users\neeld\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\neeld\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\neeld\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
import pandas as pd

input_data = pd.DataFrame([[rainfall, rain_intensity, rain_flag]],
                          columns=['rainfall', 'rain_intensity', 'rain_flag'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[102], line 3
#       1 import pandas as pd
# ----> 3 input_data = pd.DataFrame([[rainfall, rain_intensity, rain_flag]],
#       4                           columns=['rainfall', 'rain_intensity', 'rain_flag'])
#
# NameError: name 'rainfall' is not defined

# %%
predict_orders(5)
# Out:
# C:\Users\neeld\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# np.float64(284.7217493809072)

# %%
rainfall = 5
rain_intensity = rainfall * 10
rain_flag = 1 if rainfall > 2 else 0

input_data = pd.DataFrame([[rainfall, rain_intensity, rain_flag]],
                          columns=['rainfall', 'rain_intensity', 'rain_flag'])

rf_model.predict(input_data)
# Out:
# array([284.72174938])

# %%
def predict_orders(rainfall):
    import pandas as pd
    
    rain_intensity = rainfall * 10
    rain_flag = 1 if rainfall > 2 else 0
    
    input_data = pd.DataFrame([[rainfall, rain_intensity, rain_flag]],
                              columns=['rainfall', 'rain_intensity', 'rain_flag'])
    
    prediction = rf_model.predict(input_data)
    
    return prediction[0]

# %%
print(predict_orders(1))
print(predict_orders(5))
print(predict_orders(10))
# Out:
# 274.9020037370117
# 284.7217493809072
# 270.92554267228786

# %%
from sklearn.metrics import mean_absolute_error, r2_score

y_pred = rf_model.predict(X)

print("MAE:", mean_absolute_error(y, y_pred))
print("R2 Score:", r2_score(y, y_pred))
# Out:
# MAE: 160.02992418280172
# R2 Score: 0.0008398054870921712

# %%
import joblib

joblib.dump(rf_model, "model.pkl")
# Out:
# ['model.pkl']

# %%
rf_model = joblib.load("model.pkl")

# %%
# Advanced feature engineering
merged_df['income_per_order'] = merged_df['real_income'] / (merged_df['estimated_orders'] + 1)
merged_df['rain_income_interaction'] = merged_df['rainfall'] * merged_df['real_income']
merged_df['log_income'] = np.log1p(merged_df['real_income'])

# %%
merged_df['income_per_order'] = merged_df['real_income'] / (merged_df['estimated_orders'] + 1)
merged_df['rain_income_interaction'] = merged_df['rainfall'] * merged_df['real_income']
merged_df['log_income'] = np.log1p(merged_df['real_income'])

# %%
features = merged_df[
    ['rainfall', 'rain_intensity', 'rain_flag',
     'rain_income_interaction', 'log_income']
]

target = merged_df['estimated_orders']

features = features.dropna()
target = target.loc[features.index]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    features, target, test_size=0.2, random_state=42
)

# %%
from sklearn.ensemble import RandomForestRegressor

rf_model = RandomForestRegressor(
    n_estimators=300,
    max_depth=10,
    min_samples_split=5,
    random_state=42
)

rf_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=10, min_samples_split=5, n_estimators=300,
#                       random_state=42)

# %%
from sklearn.metrics import mean_absolute_error, r2_score

y_pred = rf_model.predict(X_test)

print("MAE:", mean_absolute_error(y_test, y_pred))
print("R2 Score:", r2_score(y_test, y_pred))
# Out:
# MAE: 0.128499774827166
# R2 Score: 0.9992757926767499

# %%
def predict_orders(rainfall):
    import pandas as pd
    import numpy as np

    rain_intensity = rainfall * 10
    rain_flag = 1 if rainfall > 2 else 0

    avg_income = merged_df['real_income'].mean()

    rain_income_interaction = rainfall * avg_income
    log_income = np.log1p(avg_income)

    input_data = pd.DataFrame(
        [[rainfall, rain_intensity, rain_flag,
          rain_income_interaction, log_income]],
        columns=[
            'rainfall', 'rain_intensity', 'rain_flag',
            'rain_income_interaction', 'log_income'
        ]
    )

    prediction = rf_model.predict(input_data)
    return prediction[0]

# %%
print(predict_orders(1))
print(predict_orders(5))
print(predict_orders(10))
# Out:
# 275.81832302440097
# 275.81832302440097
# 275.81832302440097

# %%
features = merged_df[
    ['rainfall', 'rain_intensity', 'rain_flag']
]

# %%
rf_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=10, min_samples_split=5, n_estimators=300,
#                       random_state=42)

# %%
features = merged_df[
    ['rainfall', 'rain_intensity', 'rain_flag']
]

target = merged_df['estimated_orders']

features = features.dropna()
target = target.loc[features.index]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    features, target, test_size=0.2, random_state=42
)

# %%
rf_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=10, min_samples_split=5, n_estimators=300,
#                       random_state=42)

# %%
def predict_orders(rainfall):
    import pandas as pd

    rain_intensity = rainfall * 10
    rain_flag = 1 if rainfall > 2 else 0

    input_data = pd.DataFrame(
        [[rainfall, rain_intensity, rain_flag]],
        columns=['rainfall', 'rain_intensity', 'rain_flag']
    )

    prediction = rf_model.predict(input_data)
    return prediction[0]

# %%
print(predict_orders(1))
print(predict_orders(5))
print(predict_orders(10))
# Out:
# 274.01641790279376
# 289.97210510419853
# 271.7786351681569

# %%
from sklearn.metrics import mean_absolute_error, r2_score

y_pred = rf_model.predict(X_test)

print("MAE:", mean_absolute_error(y_test, y_pred))
print("R2 Score:", r2_score(y_test, y_pred))
# Out:
# MAE: 156.82633833602824
# R2 Score: -0.0004600936145173762

# %%
import joblib
joblib.dump(rf_model, "rainfall_model.pkl")
# Out:
# ['rainfall_model.pkl']

# %%
import joblib
joblib.dump(rf_model, "rainfall_model.pkl")
# Out:
# ['rainfall_model.pkl']

# %%
merged_df['rolling_rainfall'] = merged_df['rainfall'].rolling(window=3).mean()
merged_df['rain_squared'] = merged_df['rainfall'] ** 2

# %%
features = merged_df[
    ['rainfall', 'rain_intensity', 'rain_flag',
     'rain_squared', 'rolling_rainfall']
]

target = merged_df['estimated_orders']

features = features.dropna()
target = target.loc[features.index]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    features, target, test_size=0.2, random_state=42
)

from sklearn.ensemble import RandomForestRegressor

rf_model = RandomForestRegressor(
    n_estimators=500,
    max_depth=12,
    min_samples_split=4,
    random_state=42
)

rf_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=12, min_samples_split=4, n_estimators=500,
#                       random_state=42)

# %%
from sklearn.metrics import mean_absolute_error, r2_score

y_pred = rf_model.predict(X_test)

print("MAE:", mean_absolute_error(y_test, y_pred))
print("R2 Score:", r2_score(y_test, y_pred))
# Out:
# MAE: 160.1845704581161
# R2 Score: -0.010932391504254069

# %%
from xgboost import XGBRegressor

xgb_model = XGBRegressor(
    n_estimators=500,
    learning_rate=0.05,
    max_depth=6,
    random_state=42
)

xgb_model.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=500,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
y_pred_xgb = xgb_model.predict(X_test)

print("XGB MAE:", mean_absolute_error(y_test, y_pred_xgb))
print("XGB R2:", r2_score(y_test, y_pred_xgb))
# Out:
# XGB MAE: 161.47163305068267
# XGB R2: -0.021548406898723504

# %%
print(rf_model.feature_names_in_)
# Out:
# ['rainfall' 'rain_intensity' 'rain_flag' 'rain_squared' 'rolling_rainfall']

# %%
import numpy as np

merged_df['rain_intensity'] = merged_df['rainfall'] * 10
merged_df['rain_flag'] = merged_df['rainfall'].apply(lambda x: 1 if x > 2 else 0)

# NEW features (important!)
merged_df['rain_squared'] = merged_df['rainfall'] ** 2
merged_df['rolling_rainfall'] = merged_df['rainfall'].rolling(3).mean()

merged_df = merged_df.dropna()

# %%
print(rf_model.feature_names_in_)
# Out:
# ['rainfall' 'rain_intensity' 'rain_flag' 'rain_squared' 'rolling_rainfall']

# %%
merged_df = merged_df.dropna()

# %%
import pandas as pd

rainfall_values = list(range(0, 21))
data = []

for r in rainfall_values:
    rain_intensity = r * 10
    rain_flag = 1 if r > 2 else 0
    rain_squared = r ** 2
    rolling_rainfall = r  # simple assumption

    # EXACT SAME FEATURES AS MODEL
    input_data = pd.DataFrame({
        'rainfall': [r],
        'rain_intensity': [rain_intensity],
        'rain_flag': [rain_flag],
        'rain_squared': [rain_squared],
        'rolling_rainfall': [rolling_rainfall]
    })

    pred = rf_model.predict(input_data)[0]
    data.append([r, pred])

df_pred = pd.DataFrame(data, columns=["Rainfall", "Predicted_Orders"])

df_pred.to_csv("prediction_data.csv", index=False)

print("✅ CSV CREATED SUCCESSFULLY")
df_pred.head()
# Out:
# ✅ CSV CREATED SUCCESSFULLY
#    Rainfall  Predicted_Orders
# 0         0        247.626544
# 1         1        247.626544
# 2         2        265.598906
# 3         3        276.884773
# 4         4        277.492431

# %%
import os
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'analysis.ipynb', 'model.pkl', 'prediction_data.csv', 'rainfall_model.pkl']

# %%
import os
print(os.getcwd())
# Out:
# D:\Gig_Economy_Project\notebooks
